# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Cargar datos

# %%
df = pd.read_csv('homeo.csv')
df.head(10)
# Out:
#    EXPEDIENTE    REGISTRO_SANITARIO FECHA_EXPEDICION FECHA_VENCIMIENTO  \
# 0      207398            NO REPORTA       1999-01-01               NaN
# 1      207276            NO REPORTA       1999-01-01               NaN
# 2      206425            NO REPORTA       1999-01-01               NaN
# 3      204949  INVIMA 2001N-0000008       2001-09-17        2011-10-05
# 4      216969  INVIMA 2002N-0000105       2002-11-29        2012-12-17
# 5      212562       PFM2007-0000548       2007-02-22        2017-03-08
# 6      212562       PFM2007-0000548       2007-02-22        2017-03-08
# 7       41476              M-011112       1998-07-17        2008-07-14
# 8       41476              M-011112       1998-07-17        2008-07-14
# 9       42965       INVIMA N-000274       2000-06-09        2010-06-07
#
#                                             PRODUCTO TIPOPRODUCTO  \
# 0                              EXTRACTO DE VALERIANA   NO REPORTA
# 1                                          ARLELLIUM   NO REPORTA
# 2                                             DIULED   NO REPORTA
# 3               BRONQUIOLIV MALVA SYLVESTRIS - MALVA   NO REPORTA
# 4  TARAXACUM OFFICINALIS DIENTE DE LEON SOLUCION ...   NO REPORTA
# 5                                   GINSANA CAPSULAS   NO REPORTA
# 6                                   GINSANA CAPSULAS   NO REPORTA
# 7                                      HEPAGOT GOTAS   NO REPORTA
# 8                                      HEPAGOT GOTAS   NO REPORTA
# 9                                    ORTIGA TABLETAS   NO REPORTA
#
#   TIPO_IDENTIFICACION_TITULAR  IDENTIFICACION_TITULAR  \
# 0                          NI              8603519554
# 1                          NI              8603519654
# 2                          NI              8603519654
# 3                          NI              8603519654
# 4                          NI              8603519654
# 5                          NI                    2188
# 6                          NI                    2188
# 7                          CS                    5110
# 8                          CS                    5110
# 9                          NI              8001112574
#
#                            TITULAR         DIRECCIÓN_TITULAR  ...  \
# 0     LABORATORIOS PRONABELL S A S   CARRERA 12 NO 24 B - 45  ...
# 1      LABORATORIOS PRONABELL LTDA      CARRERA 12 NO 24B 45  ...
# 2      LABORATORIOS PRONABELL LTDA      CARRERA 12 NO 24B 45  ...
# 3      LABORATORIOS PRONABELL LTDA      CARRERA 12 NO 24B 45  ...
# 4      LABORATORIOS PRONABELL LTDA      CARRERA 12 NO 24B 45  ...
# 5  GPL GINSANA PRODUCTS LUGANO S A    CANTON DE TICINO SUIZA  ...
# 6  GPL GINSANA PRODUCTS LUGANO S A    CANTON DE TICINO SUIZA  ...
# 7             FERNANDO LEON CHACON                NO REPORTA  ...
# 8             FERNANDO LEON CHACON                NO REPORTA  ...
# 9        LABORATORIOS MEDICK S A S  CALLE 44 A NO 48 A - 120  ...
#
#   ESTADO_REGISTRO                                     MARCA  \
# 0          NEGADO                                  VALETOR1
# 1          NEGADO                                NO REPORTA
# 2          NEGADO                                    DIULED
# 3         VENCIDO                                EXPECTORIN
# 4         VENCIDO                                    LEDMAR
# 5       CANCELADO                                   GINSANA
# 6       CANCELADO                                   GINSANA
# 7         VENCIDO  SE ENCUENTRA EN TRAMITE LA MARCA HEPAGOT
# 8         VENCIDO  SE ENCUENTRA EN TRAMITE LA MARCA HEPAGOT
# 9         VENCIDO                                       NaN
#
#                                     PRINCIPIO_ACTIVO FORMA_FARMACEUTICA  \
# 0                                          VALERIANA      SOLUCION ORAL
# 1                               EXTRACTO SECO DE AJO         NO REPORTA
# 2    MATERIAL HS TARAXACUM OFFICINALE DIENTE DE LEÓN             JARABE
# 3            MALVA MALVA SYLVESTRIS - HOJAS Y FLORES      SOLUCION ORAL
# 4  EXTRACTO SECO DE DIENTE DE LEON TARAXACUM OFFI...      SOLUCION ORAL
# 5  EXTRACTO ESTANDARIZADO DE PANAX GINSENG G115 E...     CAPSULA BLANDA
# 6  EXTRACTO ESTANDARIZADO DE PANAX GINSENG G115 E...     CAPSULA BLANDA
# 7                                TINTURA DE RUIBARBO         NO REPORTA
# 8                                   TINTURA DE BOLDO         NO REPORTA
# 9                       ORTIGA URTICA URENS L -HOJAS            TABLETA
#
#   USOTERAPEUTICO INDICACIONES  \
# 0      NO APLICA      SEDANTE
# 1     NO REPORTA   NO REPORTA
# 2      NO APLICA    DIURÉTICO
# 3   EXPECTORANTE   NO REPORTA
# 4      DIURETICO   NO REPORTA
# 5    ESTIMULANTE   NO REPORTA
# 6    ESTIMULANTE   NO REPORTA
# 7     NO REPORTA   NO REPORTA
# 8     NO REPORTA   NO REPORTA
# 9      DIURÉTICO   NO REPORTA
#
#                   CONTRA INDICACIONES Y ADVERTENCIAS          CONDICION_VENTA  \
# 0  NO PROLONGAR SU USO POR MÁS DE 2 MESES DEBE TE...  SIN FORMULA FACULTATIVA
# 1                                         NO REPORTA               NO REPORTA
# 2  EMBARAZO LACTANCIA MENORES DE 17 AÑOS Y PACIEN...  SIN FORMULA FACULTATIVA
# 3      HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES  SIN FORMULA FACULTATIVA
# 4  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 5  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 6  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 7                                         NO REPORTA               NO REPORTA
# 8                                         NO REPORTA               NO REPORTA
# 9  EMBARAZO LACTANCIA MENORES DE 17 AÑOS PACIENTE...  SIN FORMULA FACULTATIVA
#
#       VIAUTIL                              PRESENTACIONCOMERCIAL
# 0      2 AÑOS  CAJA POR UN FRASCO DE COLOR AMBAR TIPO II POR ...
# 1  NO REPORTA                             FRASCO POR 30 Y 120 ML
# 2      2 AÑOS  CAJA DE CARTON CON UN FRASCO DE VIDRIO TIPO II...
# 3       1 AÑO  CAJA POR UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 4       1 AÑO  CAJA CON UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 5      2 AÑOS  CAJA DE CARTÓN CON SATCHET DE ALUMINIO Y BLIST...
# 6      2 AÑOS  CAJA DE CARTÓN CON SATCHET DE ALUMINIO Y BLIST...
# 7  NO REPORTA  FRASCO EN VIDRIO AZUL VERDE TIPO III CON TAPA ...
# 8  NO REPORTA  FRASCO EN VIDRIO AZUL VERDE TIPO III CON TAPA ...
# 9      2 AÑOS  FRASCO DE POLIETILENO DE ALTA DENSIDAD COLOR V...
#
# [10 rows x 23 columns]

# %% [markdown]
# Le damos print a los nombres de las columnas para saber con que vamos a trabajar.

# %%
nombre_columna = df.columns.to_list()
nombre_columna
# Out:
# ['EXPEDIENTE',
#  'REGISTRO_SANITARIO',
#  'FECHA_EXPEDICION',
#  'FECHA_VENCIMIENTO',
#  'PRODUCTO',
#  'TIPOPRODUCTO',
#  'TIPO_IDENTIFICACION_TITULAR',
#  'IDENTIFICACION_TITULAR',
#  'TITULAR',
#  'DIRECCIÓN_TITULAR',
#  'CIUDAD_TITULAR',
#  'ROL',
#  'MODALIDAD',
#  'ESTADO_REGISTRO',
#  'MARCA',
#  'PRINCIPIO_ACTIVO',
#  'FORMA_FARMACEUTICA',
#  'USOTERAPEUTICO',
#  'INDICACIONES',
#  'CONTRA INDICACIONES Y ADVERTENCIAS',
#  'CONDICION_VENTA',
#  'VIAUTIL',
#  'PRESENTACIONCOMERCIAL']

# %% [markdown]
# Se borran las columnas que no nos interesan en el analisis (Documentacion personal y de contacto)

# %%
df = df.drop(['TIPO_IDENTIFICACION_TITULAR', 'IDENTIFICACION_TITULAR', 'DIRECCIÓN_TITULAR'], axis=1)
df.head(5)
# Out:
#    EXPEDIENTE    REGISTRO_SANITARIO FECHA_EXPEDICION FECHA_VENCIMIENTO  \
# 0      207398            NO REPORTA       1999-01-01               NaN
# 1      207276            NO REPORTA       1999-01-01               NaN
# 2      206425            NO REPORTA       1999-01-01               NaN
# 3      204949  INVIMA 2001N-0000008       2001-09-17        2011-10-05
# 4      216969  INVIMA 2002N-0000105       2002-11-29        2012-12-17
#
#                                             PRODUCTO TIPOPRODUCTO  \
# 0                              EXTRACTO DE VALERIANA   NO REPORTA
# 1                                          ARLELLIUM   NO REPORTA
# 2                                             DIULED   NO REPORTA
# 3               BRONQUIOLIV MALVA SYLVESTRIS - MALVA   NO REPORTA
# 4  TARAXACUM OFFICINALIS DIENTE DE LEON SOLUCION ...   NO REPORTA
#
#                         TITULAR CIUDAD_TITULAR         ROL          MODALIDAD  \
# 0  LABORATORIOS PRONABELL S A S          FUNZA  FABRICANTE  FABRICAR Y VENDER
# 1   LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE  FABRICAR Y VENDER
# 2   LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE  FABRICAR Y VENDER
# 3   LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE  FABRICAR Y VENDER
# 4   LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE  FABRICAR Y VENDER
#
#   ESTADO_REGISTRO       MARCA  \
# 0          NEGADO    VALETOR1
# 1          NEGADO  NO REPORTA
# 2          NEGADO      DIULED
# 3         VENCIDO  EXPECTORIN
# 4         VENCIDO      LEDMAR
#
#                                     PRINCIPIO_ACTIVO FORMA_FARMACEUTICA  \
# 0                                          VALERIANA      SOLUCION ORAL
# 1                               EXTRACTO SECO DE AJO         NO REPORTA
# 2    MATERIAL HS TARAXACUM OFFICINALE DIENTE DE LEÓN             JARABE
# 3            MALVA MALVA SYLVESTRIS - HOJAS Y FLORES      SOLUCION ORAL
# 4  EXTRACTO SECO DE DIENTE DE LEON TARAXACUM OFFI...      SOLUCION ORAL
#
#   USOTERAPEUTICO INDICACIONES  \
# 0      NO APLICA      SEDANTE
# 1     NO REPORTA   NO REPORTA
# 2      NO APLICA    DIURÉTICO
# 3   EXPECTORANTE   NO REPORTA
# 4      DIURETICO   NO REPORTA
#
#                   CONTRA INDICACIONES Y ADVERTENCIAS          CONDICION_VENTA  \
# 0  NO PROLONGAR SU USO POR MÁS DE 2 MESES DEBE TE...  SIN FORMULA FACULTATIVA
# 1                                         NO REPORTA               NO REPORTA
# 2  EMBARAZO LACTANCIA MENORES DE 17 AÑOS Y PACIEN...  SIN FORMULA FACULTATIVA
# 3      HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES  SIN FORMULA FACULTATIVA
# 4  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
#
#       VIAUTIL                              PRESENTACIONCOMERCIAL
# 0      2 AÑOS  CAJA POR UN FRASCO DE COLOR AMBAR TIPO II POR ...
# 1  NO REPORTA                             FRASCO POR 30 Y 120 ML
# 2      2 AÑOS  CAJA DE CARTON CON UN FRASCO DE VIDRIO TIPO II...
# 3       1 AÑO  CAJA POR UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 4       1 AÑO  CAJA CON UN FRASCO DE VIDRIO TIPO II COLOR AMB...

# %% [markdown]
# Se borran las filas con datos faltantes

# %%
df = df.dropna()
df.head(5)
# Out:
#    EXPEDIENTE    REGISTRO_SANITARIO FECHA_EXPEDICION FECHA_VENCIMIENTO  \
# 3      204949  INVIMA 2001N-0000008       2001-09-17        2011-10-05
# 4      216969  INVIMA 2002N-0000105       2002-11-29        2012-12-17
# 5      212562       PFM2007-0000548       2007-02-22        2017-03-08
# 6      212562       PFM2007-0000548       2007-02-22        2017-03-08
# 7       41476              M-011112       1998-07-17        2008-07-14
#
#                                             PRODUCTO TIPOPRODUCTO  \
# 3               BRONQUIOLIV MALVA SYLVESTRIS - MALVA   NO REPORTA
# 4  TARAXACUM OFFICINALIS DIENTE DE LEON SOLUCION ...   NO REPORTA
# 5                                   GINSANA CAPSULAS   NO REPORTA
# 6                                   GINSANA CAPSULAS   NO REPORTA
# 7                                      HEPAGOT GOTAS   NO REPORTA
#
#                            TITULAR CIUDAD_TITULAR         ROL  \
# 3      LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE
# 4      LABORATORIOS PRONABELL LTDA          FUNZA  FABRICANTE
# 5  GPL GINSANA PRODUCTS LUGANO S A     NO REPORTA  FABRICANTE
# 6  GPL GINSANA PRODUCTS LUGANO S A     NO REPORTA  IMPORTADOR
# 7             FERNANDO LEON CHACON       MEDELLIN  FABRICANTE
#
#            MODALIDAD ESTADO_REGISTRO  \
# 3  FABRICAR Y VENDER         VENCIDO
# 4  FABRICAR Y VENDER         VENCIDO
# 5  IMPORTAR Y VENDER       CANCELADO
# 6  IMPORTAR Y VENDER       CANCELADO
# 7  FABRICAR Y VENDER         VENCIDO
#
#                                       MARCA  \
# 3                                EXPECTORIN
# 4                                    LEDMAR
# 5                                   GINSANA
# 6                                   GINSANA
# 7  SE ENCUENTRA EN TRAMITE LA MARCA HEPAGOT
#
#                                     PRINCIPIO_ACTIVO FORMA_FARMACEUTICA  \
# 3            MALVA MALVA SYLVESTRIS - HOJAS Y FLORES      SOLUCION ORAL
# 4  EXTRACTO SECO DE DIENTE DE LEON TARAXACUM OFFI...      SOLUCION ORAL
# 5  EXTRACTO ESTANDARIZADO DE PANAX GINSENG G115 E...     CAPSULA BLANDA
# 6  EXTRACTO ESTANDARIZADO DE PANAX GINSENG G115 E...     CAPSULA BLANDA
# 7                                TINTURA DE RUIBARBO         NO REPORTA
#
#   USOTERAPEUTICO INDICACIONES  \
# 3   EXPECTORANTE   NO REPORTA
# 4      DIURETICO   NO REPORTA
# 5    ESTIMULANTE   NO REPORTA
# 6    ESTIMULANTE   NO REPORTA
# 7     NO REPORTA   NO REPORTA
#
#                   CONTRA INDICACIONES Y ADVERTENCIAS          CONDICION_VENTA  \
# 3      HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES  SIN FORMULA FACULTATIVA
# 4  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 5  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 6  HIPERSENSIBILIDAD A ALGUNO DE SUS COMPONENTES ...  SIN FORMULA FACULTATIVA
# 7                                         NO REPORTA               NO REPORTA
#
#       VIAUTIL                              PRESENTACIONCOMERCIAL
# 3       1 AÑO  CAJA POR UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 4       1 AÑO  CAJA CON UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 5      2 AÑOS  CAJA DE CARTÓN CON SATCHET DE ALUMINIO Y BLIST...
# 6      2 AÑOS  CAJA DE CARTÓN CON SATCHET DE ALUMINIO Y BLIST...
# 7  NO REPORTA  FRASCO EN VIDRIO AZUL VERDE TIPO III CON TAPA ...
